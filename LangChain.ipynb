# %% [markdown]
# # LangChain Roadmap
# ---
# 1. Fundamentals
#     - What is LangChain
#     - LangChain Components
#     - Models
#     - Prompts
#     - Parsing Outputs
#     - Runnables and LCEL
#     - Chains
#     - Memory
# 2. RAG
#     - Document Leaders
#     - Text Splitters
#     - Embeddings
#     - Vector Stores
#     - Retrievers
#     - Building a RAG Application
# 3. Agents
#     - Tools and Toolkits
#     - Tool Calling
#     - Building an AI Agent

# %% [markdown]
# ## LangChain Main components:
# ---
# 1. Models
# 2. Prompts
# 3. Chains
# 4. Memory
# 5. Indexes
# 6. Agents
#
# ---

# %% [markdown]
# # 1. Models

# %%
from dotenv import load_dotenv
import os
import json


load_dotenv()
# Out:
# False

# %%
# # Open AI Model Structure
# from openai import OpenAI
# client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# completion = client.chat.completions.create(
#     model="gpt-4o-mini",
#     messages=[
#         {
#             "role": "system",
#             "content": "You are a helpful assistant."
#         },
#         {
#             "role": "user",
#             "content": "Write a haiku about recursion in programming."
#         }
#     ]
# )
# print(completion.choices[0].message)





# # Updated LangChain Structure
# from langchain_openai import ChatOpenAI
# model = ChatOpenAI(
#     model='gpt-4o-mini',
#     temperature=0
# )
# result = model.invoke("Now divide the result by 1.5")

# print(result.content)

# %%
# # Anthropic Model Structure
# import anthropic
# client = anthropic.Anthropic(api_key=os.getenv("ANTHROPIC_API_KEY"))

# message = client.messages.create(
#     model="claude-sonnet-4-5",
#     max_tokens=1000,
#     temperature=0.7,
#     system="You are a world class poet. Responce only with short poems.",
#     messages=[
#         {
#             "role": "system",
#             "content": [
#                 {
#                     "type": "text",
#                     "text": "Why is the ocean blue?"
#                 }
#             ]
#         }
#     ]
# )




# # Updated LangChain Structure
# from langchain_anthropic import ChatAnthropic

# model = ChatAnthropic(
#     model="claude-sonnet-4-5",
#     temperature=0
# )

# result = model.invoke("Hi, Tell me about your self")

# print(result.content)

# %%
import langchain
print(langchain.__version__)
# Out:
# 1.3.14
